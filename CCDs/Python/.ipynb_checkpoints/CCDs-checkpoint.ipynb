# %%
# IMPORTS #

# For handeling FITS files
from astropy.io import fits

import numpy as np
from matplotlib import pyplot as plt

# %%
image = fits.open(r"C:\Users\hollm\OneDrive\Desktop\College\Physics\UCD_PASS_Labs\CCDs\Data_D1\daragh_ccd\Mg\Mg_32.fit")

# %%
print(np.shape(image[0].data))
# Out:
# (1039, 1391)

# %%
pixel_values = image[0].data
plt.imshow(pixel_values,vmin=0,vmax=50000, cmap="Greys_r")
plt.colorbar()

# %%
line_values = image[0].data[800]
print(max(line_values))
# Out:
# 47908

# %%
x= list()
y= list()

i = 0
for el in line_values:
    x.append(i)
    y.append(el)
    
    i+=1
    
plt.plot(x, y)
